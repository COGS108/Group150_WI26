# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Who Gets to Sleep? Demographic Disparities in Sleep Duration and Daytime Impairment Among U.S. Adults (18+)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [X] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# Sleep is a fundamental component of health and daily functioning, yet insufficient sleep remains a widespread public health concern in the United States. Research consistently shows that sleep disparities are not randomly distributed. Demographic and socioeconomic factors including age, sex, race/ethnicity, education, and income are associated with both how long people sleep and how well they function during the day. Despite growing awareness, less attention has been paid to how these factors jointly predict not just sleep duration but also daytime functional and cognitive impairment, particularly after accounting for mental health status, which is closely intertwined with sleep health.
#
# To address this gap, we analyzed two large nationally representative datasets: the National Health and Nutrition Examination Survey (NHANES 2021) and the Behavioral Risk Factor Surveillance System (BRFSS 2022) encompassing over 350,000 U.S. adults aged 18 and older. We began with summary statistics and distribution plots to characterize sleep duration, mental health days, income, and age across demographic groups and by sex. We then fit ordinary least squares regression models to examine predictors of sleep duration in both datasets, and logistic regression models to identify predictors of self-reported daytime functional impairment (difficulty doing errands alone) and cognitive impairment (difficulty concentrating or remembering), adjusting for mental health status throughout.
#
# Both OLS regression models reached statistical significance across datasets, confirming that demographic and socioeconomic variables jointly predict sleep duration even if individual effect sizes were modest. The logistic regression for functional impairment explained approximately 15% of the variation in that outcome (pseudo R-squared = 0.147), a meaningful fit for a binary outcome model, while the cognitive impairment model explained roughly 2%. Income and mental health days were among the strongest predictors across all models. Higher income was associated with significantly lower odds of functional impairment, while more poor mental health days were associated with greater impairment of both types. Racial and ethnic disparities were also evident, particularly for cognitive impairment. Sex was a significant predictor of functional but not cognitive impairment. Together, these results suggest that sleep-related disparities are most visible in daytime functioning outcomes and are strongly shaped by socioeconomic conditions and mental health status, underscoring the need for population-level interventions that address the structural determinants of sleep health

# %% [markdown]
# ## Authors
# - Jaidy Leyva: Software, Experimental investigation, Project administration, Writing - original draft, review & editing
# - Karen Lie: Software, Data curation, Conceptualization, Visualization
# - Lavinia Lim: Conceptualization, Methodology, Analysis, Writing - original draft
# - Koushik Karthikeyan: Background research, Software, Analysis, Visualization, Writing - original dr

# %% [markdown]
# ## Research Question

# %% [markdown]
# To what extent are age, sex, race/ethnicity, education and socioeconomic status predictive of disparities in sleep duration (hours per night) and sleep-related impairment (self-reported daytime functional and cognitive limitations), after adjusting for self-reported mental health status, among U.S. adults (18+ years old)?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Sleep is a core factor in overall health and daily functioning, and public health guidance typically advises <7 hours/night as insufficient sleep for adults.<sup><a href="#ref1" id="cite1">1</a></sup>
#
# National surveillance data show that insufficient sleep is common in the U.S. and also that insufficient sleep differs across demographic groups.
# For example, the CDC analysis of the Behavioral Risk Factor Surveillance System found that only about two-thirds of U.S. adults reported “healthy sleep duration” (≥7 hours), with a lower rate among several racial/ethnic minority groups and among adults without higher education, this shows that there is broader concern for the sleep-health of the overall population rather than individual sleep choices.<sup><a href="#ref2" id="cite2">2</a></sup>
# Therefore, sleep duration is a population-level concern.<sup><a href="#ref2" id="cite2b">2</a></sup>
#
# A research paper by the National Library of Medicine has investigated why sleep duration varies by age, sex, race/ethnicity, and socioeconomic status. The medical reviews emphasize that “race/ethnicity” is a social category that can include potential exposures—such as discrimination, poor neighborhood conditions, and working constraints—that ultimately play a role in sleep opportunity and timing.<sup><a href="#ref3" id="cite3">3</a></sup>
# Large U.S. survey studies show that disparities stay even after accounting for many variables. For instance, an NHIS trends analysis reported increases in self-reported short sleep in recent years that were especially pronounced among Black and Hispanic adults even after adjusting for demographic and socioeconomic factors, raising concern that widening sleep disparities may lead to other health inequalities over time.<sup><a href="#ref4" id="cite4">4</a></sup>
# Longitudinal evidence also suggests that short sleep is more common in lower income/education groups and among some racial/ethnic minority groups, with socioeconomic context and living conditions explaining more of the disparity than individual health behaviors alone.<sup><a href="#ref5" id="cite5">5</a></sup>
#
# Importantly, the consequences of insufficient sleep extend beyond “hours slept” to sleep-related impairment—fatigue, excessive daytime sleepiness, and reduced functioning.
# Research that took into account both sleep duration and symptoms found that lack of sleep is associated with higher levels of fatigue and daytime sleepiness, and that both education and race/ethnicity relate to multiple sleep-related symptoms, underscoring that disparities may appear in both sleep quantity and daytime impact.<sup><a href="#ref6" id="cite6">6</a></sup>
# Additionally, Mental health is central to this question because it is strongly connected with overall sleep health: evidence supports relationships between sleep disturbances and depression/anxiety, and anxiety can also cause excessive daytime sleepines.<sup><a href="#ref7" id="cite7">7</a></sup>
# Also, consistent with that, NHIS-based analysis showed that psychological distress is directly associated with unhealthy sleep duration even after adjusting for socioeconomic factors and health conditions.<sup><a href="#ref8" id="cite8">8</a></sup>
# Together, the research shows the importance of our project's focus on estimating how age, sex, race/ethnicity, and socioeconomic status relate to both sleep duration and sleep-related impairment.
#
# References:
#
# <a name="ref1"></a><a href="#cite1">^</a> Centers for Disease Control and Prevention (CDC). FastStats: Sleep in Adults (May 15, 2024). https://www.cdc.gov/sleep/data-research/facts-stats/adults-sleep-facts-and-stats.html
#
# <a name="ref2"></a><a href="#cite2">^</a> Liu Y, Wheaton AG, Chapman DP, Cunningham TJ, Lu H, Croft JB. Prevalence of Healthy Sleep Duration among Adults — United States, 2014. MMWR (2016). https://www.cdc.gov/mmwr/volumes/65/wr/mm6506a1.htm
#
# <a name="ref3"></a><a href="#cite3">^</a> Grandner MA. Sleep disparity, race/ethnicity, and socioeconomic position. Sleep Medicine (2015). https://pmc.ncbi.nlm.nih.gov/articles/PMC4631795/
#
# <a name="ref4"></a><a href="#cite4">^</a> Sheehan CM, Frochen SE, Walsemann KM, Ailshire JA. Are U.S. adults reporting less sleep? Findings from sleep duration trends in the National Health Interview Survey, 2004–2017. (2018). https://pmc.ncbi.nlm.nih.gov/articles/PMC6941709/
#
# <a name="ref5"></a><a href="#cite5">^</a> Stamatakis KA, Kaplan GA, Roberts RE. Short Sleep Duration across Income, Education and Race/Ethnic Groups: Population Prevalence and Growing Disparities over 34 Years of Follow-Up. (2007). https://pmc.ncbi.nlm.nih.gov/articles/PMC2140008/
#
# <a name="ref6"></a><a href="#cite6">^</a> Cunningham TJ, Ford ES, Chapman DP, Liu Y, Croft JB. Independent and joint associations of race/ethnicity and educational attainment with sleep-related symptoms in a population-based US sample. Preventive Medicine (2015/2016). https://stacks.cdc.gov/view/cdc/38169
#
# <a name="ref7"></a><a href="#cite7">^</a> Alvaro PK, Roberts RM, Harris JK. A systematic review assessing bidirectionality between sleep disturbances, anxiety, and depression. SLEEP (2013). https://pmc.ncbi.nlm.nih.gov/articles/PMC3669059/
#
# <a name="ref8"></a><a href="#cite8">^</a> Seixas AA, Nunes JV, Airhihenbuwa CO, et al. Linking emotional distress to unhealthy sleep duration: analysis of the 2009 National Health Interview Survey. (2015). https://pmc.ncbi.nlm.nih.gov/articles/PMC4590582/

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We hypothesize that age, sex, race/ethnicity, and socioeconomic status will be significantly associated with sleep duration and sleep-related impairment among U.S. adults, even after adjusting for self-reported mental health status. Specifically, individuals from lower socioeconomic backgrounds and racial/ethnic minority groups are expected to report shorter sleep duration and greater sleep-related impairment. This hypothesis is based on prior research showing that social and structural factors influence both sleep health and access to resources that support healthy sleep.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - National Health and Nutrition Examination Survey (NHANES) August 2021 – August 2023
#   - https://wwwn.cdc.gov/nchs/nhanes/continuousnhanes/default.aspx
#   - 5218 observations
#   - 57 variables total variables (8 used)
#   - Participant identifier, Age (years), Gender, Sleep Hours, Race/ethnicity, Income Ratio, Mental Health Score
#   - NHANES is cross-sectional, it doesn't allow for causal inference or longitudinal analysis. Many variables also require careful cleaning due to special codes used for missing responses.
# - Behavioral Risk Factor Surveillance System (BRFSS) 2022 Data
#   - https://www.cdc.gov/brfss/annual_data/2022/files/LLCP2022XPT.zip
#   - 445,132 observations
#   - 326 variables (9 used)
#   - Sleep Duration (in hrs), Age (years), Sex, Race/ethnicity, Education Level, Income, Mental health days, Functional and Cognitive impairment
#   - The BRFSS relies on self-reported sleep and mental health measures and is limited to adults, which may introduce recall bias and restrict generalizability to younger populations. Additionally, the cross-sectional design precludes causal inference.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('./modules')
import get_data
datafiles = [
    { 'url': 'https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/DEMO_L.xpt', 'filename':'DEMO_L.xpt'},
    { 'url': 'https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/SLQ_L.xpt', 'filename':'SLQ_L.xpt'},
    { 'url': 'https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/DPQ_L.xpt', 'filename':'DPQ_L.xpt'},
    {
        "url": "https://wwwn.cdc.gov/Nchs/Data/Nnyfs/Public/2012/DataFiles/Y_DEMO.xpt",
        "filename": "Y_DEMO.xpt",
    },
    {'url': 'https://www.cdc.gov/brfss/annual_data/2022/files/LLCP2022XPT.zip', 'filename': 'LLCP2022XPT.zip'},
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# ...
# Overall Download Progress:  20%|██        | 1/5 [00:00<00:02,  1.56it/s]
# Successfully downloaded: DEMO_L.xpt
# ...
# Overall Download Progress:  40%|████      | 2/5 [00:01<00:01,  1.99it/s]
# Successfully downloaded: SLQ_L.xpt
# ...
# Overall Download Progress:  60%|██████    | 3/5 [00:01<00:00,  2.14it/s]
# Successfully downloaded: DPQ_L.xpt
# ...
# Overall Download Progress:  80%|████████  | 4/5 [00:01<00:00,  2.74it/s]
# Successfully downloaded: Y_DEMO.xpt
# ...
# Overall Download Progress: 100%|██████████| 5/5 [00:03<00:00,  1.52it/s]
# Successfully downloaded: LLCP2022XPT.zip

# %% [markdown]
# ### NHANES August 2021 - August 2023 Data ###
#
# This study uses data from the National Health and Nutrition Examination Survey (NHANES), a nationally representative survey of U.S. adults. The analytic dataset was created by merging demographic, sleep questionnaire, and mental questionnaire components. After cleaning and restricting to complete cases, the final sample includes adults with valid data on sleep duration, socioeconomic characteristics, and mental health.
#
# The primary outcome is sleep duration, measured as the number of hours usually slept on weekdays or workdays. Sleep is reported in hours and ranges approximately from 2 to 14 hours in the cleaned dataset. It is top coded at 14 and bottom coded at 2. A value of 2 indicates less than 3 hours of sleep while a value of 14 indicates 14 or more hours of sleep. Short sleep is typically defined as fewer than 7 hours per night and is associated with increased health risks. Mental health was measured using a mental health score, which comprises of nine depression factors with responses scored from 0 (not at all) to 3 (nearly every day). The mental health score ranges from 0 to 27, with higher scores indicating more severe depressive symptoms.
#
# Key predictors include age (years), sex (male/female), race/ethnicity (categorized groups), education level (less than 9th grade to college graduate or above), and income-to-poverty ratio. The income-to-poverty ratio is a continuous measure comparing family income to the poverty threshold. Values below 1 indicate income below the poverty line.
#
# Some limitations should be considered. Sleep and mental health measures are self-reported, so participants may not remember their experiences perfectly or may underreport or overreport symptoms. Additionally, only participants with complete data were included, which could affect results if missing data are not random. Despite these limitations, NHANES is a large and nationally representative dataset that is appropriate for examining differences in sleep duration across demographic and socioeconomic groups.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION 
import pandas as pd
import numpy as np

demo = pd.read_sas('data/00-raw/DEMO_L.xpt')
sleep = pd.read_sas('data/00-raw/SLQ_L.xpt')
mental = pd.read_sas('data/00-raw/DPQ_L.xpt')

# Merging demographic, mental health, and sleep data to one Dataframe
df1 = demo.merge(sleep, on="SEQN", how="inner")
df1 = df1.merge(mental, on="SEQN", how="inner")

#Keeping only variables needed
columns_keep = ["SEQN","SLD012","RIDAGEYR","RIAGENDR", "RIDRETH3","INDFMPIR", "DMDEDUC2","DPQ010","DPQ020","DPQ030","DPQ040","DPQ050","DPQ060","DPQ070","DPQ080","DPQ090"]
df1 = df1[columns_keep]


# Pre-clean data summary
print("\nDataset size BEFORE cleaning:")
print(f"Observations (rows): {df1.shape[0]}")
print(f"Variables (cols): {df1.shape[1]}")

missing_summary = pd.DataFrame({
    "missing_count": df1.isna().sum(),
    "missing_percent": (df1.isna().mean() * 100).round(2)
}).sort_values("missing_percent", ascending=False)

print("\nMissingness summary (before cleaning):")
print(missing_summary)

# Flag outliers / suspicious entries 
print("\nPotential outliers / suspicious checks (before cleaning):")

# NHANES codebook notes values typically 3 to 13.5; 2 and 14 are top/bottom codes
sleep_outliers = df1[(df1["SLD012"].notna()) & ((df1["SLD012"] < 2) | (df1["SLD012"] > 14.0))]
print("Sleep outliers count (outside 3–14.0):", sleep_outliers.shape[0])

dpq_cols = ["DPQ010","DPQ020","DPQ030","DPQ040","DPQ050","DPQ060","DPQ070","DPQ080","DPQ090"]
# Mental health total score should be 0–27
for col in dpq_cols:
    print(col, "outliers count:", df1[df1[col] > 3].shape[0])

# Age (0-79); top coded at 80
age_outliers = df1[(df1["RIDAGEYR"].notna()) & ((df1["RIDAGEYR"] < 0))]
print("Age outliers count:", age_outliers.shape[0])

# Income ratio top coded at 5.00
income_outliers = df1[(df1["INDFMPIR"].notna()) & (df1["INDFMPIR"] < 0)]
print("Income ratio outliers count:", income_outliers.shape[0])

#CLEANING

#Add up all the depression data into one score
df1[dpq_cols] = df1[dpq_cols].replace({7: np.nan, 9: np.nan})
df1["mental_health_score"] = df1[dpq_cols].sum(axis=1)
df1["mental_health_score"] = df1["mental_health_score"].astype(int)
df1 = df1.drop(columns=dpq_cols)

#Rename columns
df1 = df1.rename(columns={
    "SEQN": "participant_id",
    "SLD012": "sleep_hours",
    "RIDAGEYR": "age",
    "RIAGENDR": "gender",
    "RIDRETH3": "race_ethnicity",
    "INDFMPIR": "income_ratio",
    "DMDEDUC2": "education"})

#Convert age and participant id to integer
df1["participant_id"] = df1["participant_id"].astype(int)
df1["age"] = df1["age"].astype(int)
df1["race_ethnicity"] = df1["race_ethnicity"].astype(int)

# Recode RIDRETH3 (race/ethnicity) into descriptive category labels
# Original NHANES numeric codes are converted to categorical values

race_map = {
    1: "Mexican American",
    2: "Other Hispanic",
    3: "Non-Hispanic White",
    4: "Non-Hispanic Black",
    6: "Non-Hispanic Asian",
    7: "Other/Multi"
}
df1["race_ethnicity"] = df1["race_ethnicity"].map(race_map)

# Keep only valid education levels (remove "Refused" and "Don't Know" responses)
df1 = df1[df1["education"].isin([1,2,3,4,5])]

# Recode DMDEDUC2 (education) into descriptive category labels
# Original NHANES numeric codes are converted to categorical values

education_map = {
    1: "Less than 9th grade",
    2: "9–11th grade",
    3: "High school/GED",
    4: "Some college/AA",
    5: "College graduate or above"
}
df1["education"] = df1["education"].map(education_map)

# Recode RIAGENDR (gender) into descriptive category labels
# Original NHANES numeric codes are converted to categorical values
gender_map = {
    1: "Male",
    2: "Female"
}
df1["gender"] = df1["gender"].map(gender_map)

#Remove rows with NaN values
df1 = df1.dropna()

#After Cleaning Summary

print("\nDataset size AFTER cleaning:")
print(f"Observations (rows): {df1.shape[0]}")
print(f"Variables (cols): {df1.shape[1]}")

missing_summary = pd.DataFrame({
    "missing_count": df1.isna().sum(),
    "missing_percent": (df1.isna().mean() * 100).round(2)
}).sort_values("missing_percent", ascending=False)

print("\nMissingness summary (after cleaning):")
print(missing_summary)

# Flag outliers / suspicious entries 
print("\nPotential outliers / suspicious checks (after cleaning):")

# NHANES codebook notes values typically 3 to 13.5; 2 and 14 are top/bottom codes
sleep_outliers = df1[(df1["sleep_hours"].notna()) & ((df1["sleep_hours"] < 2) | (df1["sleep_hours"] > 14.0))]
print("Sleep outliers count (outside 2–14.0):", sleep_outliers.shape[0])

# Mental health total score should be 0–27
mh_outliers = df1[(df1["mental_health_score"].notna()) & ((df1["mental_health_score"] < 0) | (df1["mental_health_score"] > 27))]
print("Mental health score outliers count:", mh_outliers.shape[0])

# Age (0-79); top coded at 80
age_outliers = df1[(df1["age"].notna()) & ((df1["age"] < 0))]
print("Age outliers count:", age_outliers.shape[0])

# Income ratio top coded at 5.00
income_outliers = df1[(df1["income_ratio"].notna()) & (df1["income_ratio"] < 0)]
print("Income ratio outliers count:", income_outliers.shape[0])

print("Observations:", df1.shape[0])
print("Variables:", df1.shape[1])
df1.to_csv("data/02-processed/nhanes2123_final.csv", index=False)

df1.head()
# Out:
# Dataset size BEFORE cleaning:
# Observations (rows): 6337
# Variables (cols): 16
#
# Missingness summary (before cleaning):
#           missing_count  missing_percent
# INDFMPIR            831            13.11
# DPQ090              831            13.11
# DPQ070              829            13.08
# DPQ080              829            13.08
# DPQ060              827            13.05
# DPQ050              824            13.00
# DPQ040              823            12.99
# DPQ030              821            12.96
# DPQ020              819            12.92
# DPQ010              818            12.91
# DMDEDUC2            273             4.31
# SLD012               65             1.03
# SEQN                  0             0.00
# RIDAGEYR              0             0.00
# RIAGENDR              0             0.00
# RIDRETH3              0             0.00
#
# Potential outliers / suspicious checks (before cleaning):
# Sleep outliers count (outside 3–14.0): 0
# DPQ010 outliers count: 21
# ...

# %% [markdown]
# ## Behavioral Risk Factor Surveillance System (BRFSS) 2022
#
# The Behavioral Risk Factor Surveillance System (BRFSS) 2022 dataset contains health-related risk behaviors, chronic health conditions, preventive service use, and sleep information for adults in the United States. BRFSS is conducted annually by the Centers for Disease Control and Prevention (CDC) as a nationally representative, state-based telephone survey. The 2022 dataset provides cross-sectional data used to monitor population health and examine disparities across states and demographic groups.
#
# Key variables include demographic characteristics (age, sex, race/ethnicity, education, income), health behaviors (smoking, alcohol use, physical activity), and health status indicators (e.g., diabetes, hypertension, obesity, general health). Age is recorded in years for adults aged 18 and older, while most other variables are categorical. Importantly, BRFSS 2022 includes a sleep duration measure that asks respondents how many hours of sleep they get in a 24-hour period. This numeric variable (typically 1–24 hours) can be analyzed continuously or categorized to identify short sleep duration (commonly defined as fewer than 7 hours). While it captures sleep quantity, it does not assess sleep quality or diagnosed sleep disorders.
#
# Several data quality considerations apply. Because BRFSS data are self-reported, responses may be affected by recall or social desirability bias. Missing data may result from nonresponse or skipped questions and may not be random. Additionally, BRFSS uses a complex sampling design with weighting, so analyses must apply survey weights to obtain nationally representative estimates. As a cross-sectional survey of noninstitutionalized adults, findings cannot establish causality.
#
# Overall, the dataset provides a structured and comprehensive foundation for analyzing adult health behaviors, chronic disease, sleep duration, and health disparities in the United States.

# %%
## CODE TO LOAD/CLEAN/TIDY/WRANGLE
import pandas as pd
import zipfile
with zipfile.ZipFile('./data/00-raw/LLCP2022XPT.zip', 'r') as z:
    print("Files inside zip:", z.namelist())
    z.extractall('./data/00-raw/')

brfss = pd.read_sas('./data/00-raw/LLCP2022XPT.zip', format="xport")

print("\n=== BRFSS SLEEP columns ===")
sleep_cols_brfss = [col for col in brfss.columns if 'SLP' in col.upper() or 'SLEEP' in col.upper() or 'SLEPT' in col.upper()]
print(sleep_cols_brfss)
# Out:
# Files inside zip: ['LLCP2022.XPT ']
#
# === BRFSS SLEEP columns ===
# ['SLEPTIM1']

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


brfss_raw = pd.read_sas('data/00-raw/LLCP2022.XPT ', format='xport')
brfss_raw.columns = [c.upper() for c in brfss_raw.columns]
print("Total raw observations:", brfss_raw.shape[0])

# ---- Selected variables ----
# SLEPTIM1  = sleep hours per night (PRIMARY outcome)
# DIFFALON  = physical/functional limitation (difficulty doing errands alone)
# CNCRDIFF = cognitive limitation (difficulty concentrating or remembering) 
# SEXVAR    = sex
# _AGEG5YR  = age group (5-year bands)
# _IMPRACE  = imputed race/ethnicity
# INCOME3   = household income (SES proxy)
# EDUCA     = education level (SES proxy)
# MENTHLTH  = poor mental health days past 30 (covariate)

cols_wanted = [
    "SLEPTIM1",
    "DIFFALON",
    "CNCRDIFF",
    "SEXVAR",
    "_AGEG5YR",
    "_IMPRACE",
    "INCOME3",
    "EDUCA",
    "MENTHLTH",
]

#keeps existing columns
cols_available = [c for c in cols_wanted if c in brfss_raw.columns]
cols_missing   = [c for c in cols_wanted if c not in brfss_raw.columns]
print("Columns found:  ", cols_available)
print("Columns missing:", cols_missing)

df = brfss_raw[cols_available].copy()

def num(s):
    return pd.to_numeric(s, errors="coerce")

#clean variables
# Sleep hours (1–24 valid; 77=don't know, 99=refused → NaN)
df["sleep_hours"] = num(df["SLEPTIM1"])
df.loc[df["sleep_hours"] > 24, "sleep_hours"] = np.nan
df.loc[df["sleep_hours"] < 1,  "sleep_hours"] = np.nan

# Physical daytime impairment — difficulty doing errands alone
df["functional_impairment"] = num(df["DIFFALON"]).map({1: 1, 2: 0})

# Cognitive impairment — binary (0=no difficulty, 1=any difficulty) to make it easier to comapre w functional impairment
df["cognitive_impairment"] = num(df["CNCRDIFF"]).map({
    1: 0,  # no difficulty
    2: 1,  # some difficulty → impaired
    3: 1,  # a lot of difficulty → impaired
    7: np.nan,
    9: np.nan
})

# Sex (matches teammates' male/female coding)
df["sex"] = num(df["SEXVAR"]).map({
    1: "male",
    2: "female",
})

# Age group — BRFSS uses 5-year bands (matches youth/adult split from teammates)
age_map = {
    1: "18-24",  2: "25-29",  3: "30-34",  4: "35-39",
    5: "40-44",  6: "45-49",  7: "50-54",  8: "55-59",
    9: "60-64", 10: "65-69", 11: "70-74", 12: "75-79",
    13: "80+"
}
df["age_group"] = num(df["_AGEG5YR"]).map(age_map)

# Race/ethnicity (matches teammates' race_ethnicity naming convention)
race_map = {
    1: "non_hispanic_white",
    2: "non_hispanic_black",
    3: "non_hispanic_asian",
    4: "non_hispanic_other",
    5: "hispanic",
    6: "multiracial",
}
df["race_ethnicity"] = num(df["_IMPRACE"]).map(race_map)

# Income — SES proxy (77=don't know, 99=refused → NaN)
df["income"] = num(df["INCOME3"])
df.loc[df["income"] >= 77, "income"] = np.nan

# Education — SES proxy (9=refused → NaN)
# Matches teammates' education levels
education_map = {
    1: "never_attended",
    2: "elementary",
    3: "some_high_school",
    4: "high_school_grad",
    5: "some_college",
    6: "college_grad",
}
df["education"] = num(df["EDUCA"]).map(education_map)
df.loc[num(df["EDUCA"]) == 9, "education"] = np.nan

# Mental health days — covariate (88=none→0, 77/99=refused/dk → NaN)
df["mental_health_days"] = num(df["MENTHLTH"])
df.loc[df["mental_health_days"] == 88, "mental_health_days"] = 0
df.loc[df["mental_health_days"] >= 77,  "mental_health_days"] = np.nan


#Pre-clean summary
print("\nDataset size BEFORE cleaning:")
print(f"Observations (rows): {df.shape[0]}")
print(f"Variables (cols):    {df.shape[1]}")

missing_summary = pd.DataFrame({
    "missing_count":   df.isna().sum(),
    "missing_percent": (df.isna().mean() * 100).round(2)
}).sort_values("missing_percent", ascending=False)
print("\nMissingness summary (before cleaning):")
print(missing_summary)

#Outlier checks
print("\nOutlier checks (before cleaning):")
sleep_out = df[(df["sleep_hours"].notna()) & 
               ((df["sleep_hours"] < 1) | (df["sleep_hours"] > 24))]
print("Sleep outliers:", sleep_out.shape[0])

mh_out = df[(df["mental_health_days"].notna()) & 
            ((df["mental_health_days"] < 0) | (df["mental_health_days"] > 30))]
print("Mental health days outliers:", mh_out.shape[0])

#Tidy dataset
keep_cols = [
    "sleep_hours",
    "functional_impairment",
    "cognitive_impairment",
    "sex",
    "age_group",
    "race_ethnicity",
    "income",
    "education",
    "mental_health_days",
]
keep_cols = [c for c in keep_cols if c in df.columns]
df_clean = df[keep_cols].dropna()

#post-clean summary
print("\nDataset size AFTER cleaning:")
print(f"Observations (rows): {df_clean.shape[0]}")
print(f"Variables (cols):    {df_clean.shape[1]}")

missing_summary_after = pd.DataFrame({
    "missing_count":   df_clean.isna().sum(),
    "missing_percent": (df_clean.isna().mean() * 100).round(2)
}).sort_values("missing_percent", ascending=False)
print("\nMissingness summary (after cleaning):")
print(missing_summary_after)

print("\nObservations:", df_clean.shape[0])
print("Variables:",    df_clean.shape[1])

df_clean.to_csv('data/02-processed/brfss2022_sleep_clean.csv', index=False)
df_clean.head()
# Out:
# Total raw observations: 445132
# Columns found:   ['SLEPTIM1', 'DIFFALON', 'CNCRDIFF', 'SEXVAR', '_AGEG5YR', '_IMPRACE', 'INCOME3', 'EDUCA', 'MENTHLTH']
# Columns missing: []
#
# Dataset size BEFORE cleaning:
# Observations (rows): 445132
# Variables (cols):    18
#
# Missingness summary (before cleaning):
#                        missing_count  missing_percent
# cognitive_impairment          422549            94.93
# CNCRDIFF                      421733            94.74
# income                         96047            21.58
# functional_impairment          25656             5.76
# DIFFALON                       23942             5.38
# INCOME3                        12932             2.91
# mental_health_days              9067             2.04
# age_group                       9079             2.04
# sleep_hours                     5453             1.23
# education                       2383             0.54
# MENTHLTH                           3             0.00
# ...

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis

# %% [markdown]
# ### Summary Statistics
# To better understand the characteristics of the dataset, we begin with summary statistics for several key variables, including sleep duration, age, income-to-poverty ratio, and mental health score. Examining these descriptive statistics provides an overview of the central tendencies, variability, and ranges of the variables included in the analysis. This helps identify general patterns in the data and ensures that the variables fall within reasonable ranges before conducting further exploratory analysis and visualizations.

# %%
#Set environment
import numpy as np
import pandas as pd
import os

df1.to_csv("data/02-processed/nhanes2123_final.csv", index=False)
df_clean.to_csv('data/02-processed/brfss2022_sleep_clean.csv', index=False)

# %%
df1 = pd.read_csv("data/02-processed/nhanes2123_final.csv")
df1[["sleep_hours", "age", "income_ratio", "mental_health_score"]].describe()
# Out:
#        sleep_hours          age  income_ratio  mental_health_score
# count  5218.000000  5218.000000  5.218000e+03          5218.000000
# mean      7.697298    53.729973  2.928582e+00             3.572250
# std       1.580541    17.059495  1.653704e+00             4.607901
# min       2.000000    20.000000  5.397605e-79             0.000000
# 25%       7.000000    39.000000  1.420000e+00             0.000000
# 50%       8.000000    57.000000  2.830000e+00             2.000000
# 75%       8.500000    68.000000  5.000000e+00             5.000000
# max      14.000000    80.000000  5.000000e+00            26.000000

# %%
df2 = pd.read_csv("data/02-processed/brfss2022_sleep_clean.csv")
df2[["sleep_hours", "age_group", "mental_health_days", "functional_impairment", "cognitive_impairment", "income"]].describe(include="all")
# Out:
#          sleep_hours age_group  mental_health_days  functional_impairment  \
# count   17791.000000     17791        17791.000000           17791.000000
# unique           NaN        13                 NaN                    NaN
# top              NaN     70-74                 NaN                    NaN
# freq             NaN      3279                 NaN                    NaN
# mean        7.149907       NaN            3.703389               0.088303
# std         1.468944       NaN            7.859252               0.283743
# min         1.000000       NaN            0.000000               0.000000
# 25%         6.000000       NaN            0.000000               0.000000
# 50%         7.000000       NaN            0.000000               0.000000
# 75%         8.000000       NaN            3.000000               0.000000
# max        22.000000       NaN           30.000000               1.000000
#
#         cognitive_impairment        income
# ...

# %% [markdown]
# ### NHANES and BRFSS Summary Statistics
# In the NHANES dataset on average, respondents report about 7.7 hours of sleep per night, with a median of 8 hours, suggesting that most individuals sleep near the recommended range. Sleep duration varies from 2 to 14 hours, indicating some variation in sleep patterns.The average age of participants is about 53.7 years, with ages ranging from 20 to 80. The income-to-poverty ratio has a mean of 2.93, showing variation in socioeconomic status across the sample. The mental health score has an average of 3.57 on a scale from 0 to 27, suggesting that most respondents report relatively low levels of depressive symptoms.
#
# Likewise, the BRFSS 2022 dataset reports sleep duration averages 7.0 hours per night (SD = 1.47), with the middle 50% of respondents sleeping between 6 and 8 hours suggesting that while the average aligns with CDC recommendations, a notable portion of adults fall below the recommended threshold. Mental health days average 4.46 poor days per month, though the median of 0 indicates the distribution is heavily right-skewed, meaning most respondents reported no poor mental health days while a smaller subset experienced significant burden. Income levels average around category 7 ($50-75k range), with the interquartile range spanning categories 5 through 9, reflecting a broad socioeconomic spread across the sample. The most represented age group is 65-69, which is consistent with known response patterns in telephone-based surveys like BRFSS.

# %% [markdown]
# ### Distribution Plots
# Next, distribution plots are used to better understand the structure of the dataset and visualize how key variables are spread across the sample, as well as any skewness or extreme values.

# %% [markdown]
# #### Figure 1a: NHANES - Sleep Distribution

# %%
df1["sleep_hours"].plot(kind="hist", bins=20)
plt.title("NHANES Distribution of Sleep Duration (Hours/Night)")
plt.xlabel("Sleep hours")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# Figure 1a shows that most respondents report sleeping between 6 and 9 hours per night, with the highest concentration around 7–8 hours, suggesting that the majority of adults fall near the recommended sleep range. The distribution is slightly right-skewed, with a notable drop-off after 8 hours and a small but visible tail of respondents reporting 10 or more hours per night. However, the presence of individuals reporting very short or very long sleep durations indicates meaningful variability in sleep behavior that may be explained by demographic and socioeconomic factors examined in subsequent analyses.

# %% [markdown]
# #### Figure 1b: BRFSS - Sleep Hour Distribution

# %%
fig, ax = plt.subplots(figsize=(8, 5))

ax.hist(df2["sleep_hours"], bins=20, color="mediumpurple", edgecolor="white")
ax.axvline(df2["sleep_hours"].mean(), color="red", linestyle="--", label=f'Mean: {df2["sleep_hours"].mean():.2f}')
ax.axvline(7, color="green", linestyle="--", label="Recommended: 7hrs")
ax.set_xlabel("Sleep Hours per Night")
ax.set_ylabel("Count")
ax.set_title("BRFSS 2022 — Sleep Duration Distribution")
ax.set_xlim(0, 25)
ax.legend()

plt.tight_layout()
plt.savefig("results/brfss_sleep_histogram.png", dpi=150)
plt.show()

# %% [markdown]
# In figure 1b, the BRFSS 2022 sleep duration distribution shows a strong concentration around 7 hours per night, with the sample mean of 7.15 hours nearly identical to the CDC recommended threshold of 7 hours, shown by the overlapping red and green dashed lines. The distribution is notably more peaked and symmetric than the NHANES dataset, with the vast majority of respondents clustering tightly between 6 and 8 hours. A small number of respondents reported extreme values at both ends. Fewer than 200 reporting under 3 hours and a visible but sparse tail extending beyond 12 hours indicating that while most adults meet recommended sleep guidelines, meaningful variability remains across the population.

# %% [markdown]
# #### Figure 2a: NHANES - Mental Health Score Distribution

# %%
# Mental health score distribution
df1["mental_health_score"].plot(kind="hist", bins=20)
plt.title("Distribution of Mental Health Score (PHQ-9 Total)")
plt.xlabel("Mental health score")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# For figure 2a, the distribution of PHQ-9 mental health scores is strongly right-skewed, with the majority of respondents scoring between 0 and 5, indicating that most adults in the NHANES sample report minimal depressive symptoms. The sharp peak at 0 suggests that a large proportion of respondents reported no depressive symptoms at all, while progressively fewer individuals report higher scores. A small but notable tail extends to scores of 20 and above, representing individuals with severe depressive symptoms. Although a minority, it is an important subgroup given the strong association between mental health and sleep quality examined in this analysis.

# %% [markdown]
# #### Figure 2b: BRFSS - Mental Health Days Distribution

# %%
fig, ax = plt.subplots(figsize=(8, 5))

ax.hist(df2["mental_health_days"], bins=31, color="mediumpurple", edgecolor="white")
ax.set_xlabel("Poor Mental Health Days (past 30)")
ax.set_ylabel("Count")
ax.set_title("BRFSS 2022 — Mental Health Days Distribution")

plt.tight_layout()
plt.savefig("results/brfss_mental_health_distribution.png", dpi=150)
plt.show()

# %% [markdown]
# Like above, figure 2b showing the BRFSS 2022 mental health days distribution, is similarly right-skewed, with the dominant peak at 0 days representing the roughly 65% of respondents who reported no poor mental health days in the past 30 days, consistent with the median of 0 from the summary statistics. The mean of 4.46 days is pulled upward by a smaller subset of respondents reporting frequent poor mental health days, including a visible spike at 30 days representing individuals who experienced poor mental health every day of the past month. This pattern of high zero-inflation combined with a heavy tail reflects the unequal distribution of mental health burden in the population and underscores why mental health is included as a covariate in the regression models rather than treated as a uniformly distributed variable.

# %% [markdown]
# #### Figure 3a: NHANES - Age Distribution

# %%
plt.figure()
df1["age"].hist(bins=20)
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("NHANES - Age Distribution of Respondents")
plt.show()

# %% [markdown]
# In figure 3a, the NHANES sample includes adults ranging from 20 to 80 years old, with representation relatively stable across younger and middle-aged groups before increasing notably among older adults. Respondent counts rise sharply around age 60, peaking near 80 years old with over 400 respondents, which reflects NHANES oversampling of older adults to ensure adequate representation of this population. This age skew toward older adults is important to keep in mind when interpreting sleep findings, as age is one of the key predictors examined in this analysis.

# %% [markdown]
# #### Figure 3b: BRFSS - Age Group Distribution

# %%
age_order = ["18-24","25-29","30-34","35-39","40-44","45-49",
             "50-54","55-59","60-64","65-69","70-74","75-79","80+"]

fig, ax = plt.subplots(figsize=(10, 5))

df2["age_group"].value_counts().reindex(age_order).plot(kind="bar", color="mediumpurple", edgecolor="white", ax=ax)
ax.set_xlabel("Age Group")
ax.set_ylabel("Count")
ax.set_title("BRFSS 2022 — Age Group Distribution")
ax.tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.savefig("results/brfss_age_distribution.png", dpi=150)
plt.show()

# %% [markdown]
# For figure 3b, the BRFSS 2022 sample spans adults from 18 to 80 and older, with a clear and consistent increase in representation across age groups. Younger adults aged 18-29 are notably underrepresented with fewer than 100 respondents each, while representation grows steadily through middle age and peaks in the 70-74 group with over 3,200 respondents. This strong skew toward older adults is typical of telephone-based surveys like BRFSS, which tend to reach older respondents more easily, and means that findings for younger age groups should be interpreted with more caution given their smaller sample sizes.

# %% [markdown]
# #### Figure 4a: NHANES - Income Ratio Distribution

# %%
plt.figure()
df1["income_ratio"].hist(bins=20)
plt.xlabel("Income to Poverty Ratio")
plt.ylabel("Count")
plt.title("Distribution of Income-to-Poverty Ratio")
plt.show()

# %% [markdown]
# In figure 4a, the income-to-poverty ratio distribution ranges from near 0 to 5, with relatively stable representation across the lower and middle range before a dramatic spike at the upper limit of 5. This sharp peak reflects the fact that NHANES top-codes the income-to-poverty ratio at 5.0, meaning all respondents with incomes five times or more above the poverty threshold are grouped into a single category, accounting for over 1,400 respondents. The broad spread across lower ratios indicates meaningful socioeconomic diversity in the sample, with a substantial number of respondents living near or below the poverty line, which is important for examining how income predicts sleep duration and daytime impairment.

# %% [markdown]
# #### Figure 4b: BRFSS - Income Distribution

# %%
income_labels = {
    1:"<$10k", 2:"$10-15k", 3:"$15-20k", 4:"$20-25k",
    5:"$25-35k", 6:"$35-50k", 7:"$50-75k", 8:"$75-100k",
    9:"$100-150k", 10:"$150-200k", 11:"$200k+"
}
income_order = list(income_labels.values())
df2["income_label"] = df2["income"].map(income_labels)

fig, ax = plt.subplots(figsize=(10, 5))

df2["income_label"].value_counts().reindex(income_order).plot(kind="bar", color="mediumpurple", edgecolor="white", ax=ax)
ax.set_xlabel("Income Level")
ax.set_ylabel("Count")
ax.set_title("BRFSS 2022 — Income Distribution")
ax.tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.savefig("results/brfss_income_distribution.png", dpi=150)
plt.show()

# %% [markdown]
# When looking at figure 4b, the BRFSS 2022 income distribution peaks at the $50-75k category with approximately 3,400 respondents, representing the most common income level in the sample. Representation increases steadily from the lowest income bracket through the $50-75k peak, then drops at the higher brackets, with the $150-200k and $200k+ groups each containing roughly 1,000 respondents. The lowest income brackets (<$10k through $20-25k) are notably underrepresented compared to middle income groups, which likely reflects both the actual U.S. income distribution and potential underresponse from lower-income populations in telephone-based surveys.
#
# Overall the sample captures a broad socioeconomic range, complementing the NHANES income-to-poverty ratio measure and supporting a comprehensive examination of SES as a predictor of sleep outcomes.

# %% [markdown]
# ### Box Plots - Sleep Disparities by Group

# %% [markdown]
# #### Figure 5a: NHANES - Sleep Duration by Gender Boxplot
# This helps examine whether men and women report different sleep durations.

# %%
plt.figure()
df1.boxplot(column="sleep_hours", by="gender")
plt.title("Sleep Duration by Gender")
plt.suptitle("")
plt.xlabel("Gender")
plt.ylabel("Sleep hours")
plt.tight_layout()
plt.show()

# %% [markdown]
# Figure 5a shows both females and males have very similar sleep duration patterns, with median sleep around 8 hours per night and nearly identical interquartile ranges spanning roughly 7 to 9 hours, suggesting that typical sleep levels are comparable across genders in this sample. Females appear to have a marginally higher median than males, though the difference is small and the overall distributions are largely overlapping. Both groups display similar spreads and include outliers at both extremes such as individuals reporting as few as 2 hours and as many as 14 hours, indicating that extreme sleep durations are not concentrated in either gender.
#
# These similarities suggest that sex alone may not be a strong predictor of sleep duration, though subtler differences may emerge after controlling for age, income, and mental health status in the regression models.

# %% [markdown]
# #### Figure 5b: BRFSS - Sleep by Gender Boxplot

# %%
fig, ax = plt.subplots(figsize=(8, 5))

df2.boxplot(column="sleep_hours", by="sex", ax=ax)
ax.set_xlabel("Sex")
ax.set_ylabel("Sleep Hours")
ax.set_title("BRFSS — Sleep Hours Distribution by Sex")
plt.suptitle("")

plt.tight_layout()
plt.savefig("results/brfss_sleep_by_sex.png", dpi=150)
plt.show()

# %% [markdown]
# In figure 5b, both males and females in the BRFSS 2022 sample averaged exactly 7 hours of sleep per night, precisely aligning with the CDC recommended threshold, which is consistent with the NHANES findings. The boxplots confirm this similarity with nearly identical medians, interquartile ranges of 6–8 hours, and comparable whisker lengths for both sexes. Both groups show a similar spread of outliers above 10 hours, indicating that extreme sleep durations are not more prevalent in one sex than the other. Taken together with the NHANES results, the consistency across both large independent datasets strengthens the conclusion that sex alone does not strongly differentiate sleep duration at the population level, though more subtle differences may only emerge after adjusting for other covariates in the regression analysis.

# %% [markdown]
# #### Figure 6a: NHANES - Sleep by Race/Ethnicity
# This helps examine racial or ethnic disparities in sleep.

# %%
plt.figure()
df1.boxplot(column="sleep_hours", by="race_ethnicity")
plt.title("Sleep Duration by Race/Ethnicity")
plt.suptitle("")
plt.xlabel("Race/Ethnicity")
plt.ylabel("Sleep hours")
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# In this figure, the median sleep duration for most groups falls between 7 and 8 hours, suggesting that typical sleep levels are relatively similar across racial and ethnic groups.
#
# Non-Hispanic White and Other Hispanic respondents appear to have slightly higher median sleep durations closer to 8 hours, while Non-Hispanic Asian respondents show a somewhat lower median around 7–7.5 hours. Some groups, particularly Non-Hispanic Black and Other Hispanic respondents, show a wider interquartile range, suggesting greater within-group variability in sleep patterns. All groups display outliers representing individuals with very short sleep durations around 2–4 hours and very long sleep durations above 11 hours. While the medians are relatively close, these differences in spread and central tendency suggest that race and ethnicity may interact with other factors such as socioeconomic status and mental health to shape sleep outcomes, which is formally tested in the regression models.

# %% [markdown]
# #### Figure 6b: BRFSS - Sleep by Race/Ethnicity

# %%
fig, ax = plt.subplots(figsize=(10, 6))

df2.boxplot(column="sleep_hours", by="race_ethnicity", ax=ax)
ax.set_xlabel("Race/Ethnicity")
ax.set_ylabel("Sleep Hours")
ax.set_title("BRFSS 2022 — Sleep Hours Distribution by Race/Ethnicity")
ax.tick_params(axis="x", rotation=45)
plt.suptitle("")

plt.tight_layout()
plt.savefig("results/brfss_sleep_by_race.png", dpi=150)
plt.show()

# %% [markdown]
# Figure 6b shows all six racial and ethnic groups show a median sleep duration of 7 hours with nearly identical interquartile ranges spanning roughly 6 to 8 hours, consistent with the NHANES findings and suggesting that race and ethnicity alone does not produce dramatic differences in sleep duration at the aggregate level. Subtle differences are visible in the whisker lengths and outlier patterns specifically in Non-Hispanic Black respondents showing a slightly wider spread of outliers on the high end, and Non-Hispanic Asian respondents having a noticeably tighter interquartile range and fewer outliers than other groups.
#
# These surface-level similarities should be interpreted cautiously, as meaningful racial disparities in sleep may only become apparent after controlling for socioeconomic status and mental health, which are unequally distributed across racial groups and are both included as covariates in the regression models.

# %% [markdown]
# #### Figure 7a: NHANES - Sleep by Education
# This helps explore whether sleep is education levels.

# %%
plt.figure()
df1.boxplot(column="sleep_hours", by="education")
plt.title("NHANES - Sleep Duration by Education Level")
plt.suptitle("")
plt.xlabel("Education")
plt.ylabel("Sleep hours")
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# For figure 7a, the median sleep duration for all groups is close to 7–8 hours per night, indicating that typical sleep levels are similar regardless of education level. The interquartile ranges for most education levels are also overlap, suggesting that the middle 50% of sleep values are similar across groups.
#
# However, individuals with 9–11th grade education appear to have slightly greater variability in sleep duration, as indicated by the wider spread between the lower and upper quartiles. In contrast, respondents with college degrees or some college education show slightly tighter distributions, suggesting more consistent sleep patterns within these groups. All education categories also contain outliers representing individuals reporting very short sleep (around 2–4 hours) or very long sleep (above 11 hours).
#
# Although the central tendencies across education groups are similar, the differences in variability suggest that education level may be associated with differences in sleep consistency rather than large shifts in typical sleep duration, and its role as a predictor is formally examined alongside income and other socioeconomic factors in the regression models.

# %% [markdown]
# #### Figure 7b: BRFSS - Sleep by Education level

# %%
fig, ax = plt.subplots(figsize=(10, 6))

df2.boxplot(column="sleep_hours", by="education", ax=ax)
ax.set_xlabel("Education Level")
ax.set_ylabel("Sleep Hours")
ax.set_title("BRFSS 2022 — Sleep Hours Distribution by Education")
ax.tick_params(axis="x", rotation=45)
plt.suptitle("")

plt.tight_layout()
plt.savefig("results/brfss_sleep_by_education.png", dpi=150)
plt.show()

# %% [markdown]
# In figure 7b, sleep duration is remarkably consistent across all education levels, with every group showing a median of 7 hours and an interquartile range of roughly 6 to 8 hours. This suggests that education level alone does not produce meaningful differences in average sleep duration at the aggregate level.
#
# Notably, the "never_attended" group has a slightly narrower spread of outliers compared to other groups, which may reflect its smaller sample size rather than a true difference in sleep patterns. However, as with race and sex, these surface-level similarities may mask underlying disparities that only emerge after accounting for income, mental health, and other confounding variables, which are formally tested in the regression models.

# %% [markdown]
# #### Figure 8a: NHANES - Sleep by Income Ratio

# %%
import seaborn as sns
df1["income_bin"] = pd.cut(df1["income_ratio"], bins=5)

plt.figure(figsize=(10, 5))

sns.boxplot(x="income_bin", y="sleep_hours", data=df1)

plt.xlabel("Income Ratio (PIR bins)")
plt.ylabel("Sleep Hours")
plt.title("NHANES — Sleep Hours by Income Ratio")

plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# Figure 8a shows shows that sleep duration is relatively consistent across different income-to-poverty ratio groups, with median sleep hours remaining around 7–8 hours for all income bins and similar variability across distributions.
#
# While there are some outliers in each group, there is no clear visual trend indicating that higher or lower income is strongly associated with changes in sleep duration. This suggests that the relationship between income and sleep duration may be modest at the aggregate level, though income emerged as a statistically significant predictor in the regression model, suggesting its effect becomes more apparent after controlling for other demographic and health variables.

# %% [markdown]
# #### Figure 8b: BRFSS - Sleep Hours by Income

# %%
import seaborn as sns

df2["income_bin"] = pd.cut(
    df2["income"],
    bins=[0, 3, 6, 9, 11],
    labels=["1–3", "4–6", "7–9", "10–11"]
)

# Plot
sns.set_style("whitegrid")
plt.figure(figsize=(8, 5))

sns.boxplot(
    x="income_bin",
    y="sleep_hours",
    data=df2)

plt.xlabel("Income Category (Binned)")
plt.ylabel("Sleep Hours")
plt.title("BRFSS 2022 — Sleep Hours by Income (Binned)")

plt.tight_layout()
plt.show()

# %% [markdown]
# Figure 8b supports this since sleep duration remains relatively consistent across all income groups in the BRFSS 2022 sample, with median sleep hours centered around 6–7 hours for the lower and middle income bins, and a marginal upward shift visible in the highest income group (10–11).
#
# The distributions overlap substantially across all bins, suggesting that income level alone does not produce large differences in typical sleep duration at the aggregate level. However, this pattern is consistent with the NHANES findings and should be interpreted alongside the regression results, where income was one of the strongest and most statistically significant predictors of functional impairment — suggesting income's role in sleep health may be more visible in daytime outcomes than in sleep duration itself.

# %% [markdown]
# #### Figure 9a: NHANES - Sleep Hours by Mental Health

# %%
df1["mh_bin"] = pd.cut(df1["mental_health_score"], bins=5)

plt.figure(figsize=(10,5))

sns.boxplot(x="mh_bin", y="sleep_hours", data=df1)

plt.xlabel("Mental Health Score (binned)")
plt.ylabel("Sleep Hours")
plt.title("Sleep Duration vs Mental Health (Binned)")

plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# In figure 9a, the binned boxplot indicates a subtle negative relationship between mental health score and sleep duration — as PHQ-9 scores increase, median sleep hours show a slight decline, dropping noticeably in the highest bin (20.8–26.0) compared to the lowest.
#
# Variability in sleep also appears to increase at higher mental health score bins, with wider interquartile ranges and more extreme values, suggesting that poorer mental health is associated with not only shorter but also more irregular sleep. While the trend is modest visually, it is consistent with the BRFSS findings and aligns with the regression results where mental health was one of the strongest and most statistically significant predictors of both sleep duration and daytime impairment across all models.

# %% [markdown]
# #### Figure 9b: BRFSS - Sleep hours by Mental Health Days

# %%
df2["mh_bin"] = pd.cut(
    df2["mental_health_days"],
    bins=[-1, 5, 10, 20, 30],
    labels=["0–5", "6–10", "11–20", "21–30"]
)

sns.set_style("whitegrid")
plt.figure(figsize=(8, 5))

sns.boxplot(
    x="mh_bin",
    y="sleep_hours",
    data=df2)

plt.xlabel("Poor Mental Health Days (binned)")
plt.ylabel("Sleep Hours")
plt.title("BRFSS 2022 — Sleep Hours vs Mental Health (Binned)")

plt.tight_layout()
plt.show()

# %% [markdown]
# Consistent with the NHANES findings, figure 9b shows the BRFSS binned boxplot has a subtle negative association between poor mental health days and sleep duration, with the most pronounced decline visible in the highest bin of 21–30 poor mental health days, where the median drops to approximately 6.5 hours compared to 7 hours in the lower bins.
#
# The spread of sleep hours also widens at higher levels of poor mental health, indicating greater variability in sleep patterns among those with more frequent mental health burden. Together with the NHANES pattern, these findings across two independent national datasets consistently support the inclusion of mental health as a key covariate in the regression models, where it emerged as one of the strongest predictors of both sleep duration and daytime functional and cognitive impairment.

# %% [markdown]
# ### Figure 10: BRFSS Daytime Functional & Cognitive Impairment Plot

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# ── Functional Impairment (DIFFALON) ─────────────────────────────────────

# Overall functional impairment rate
functional_counts = df2["functional_impairment"].value_counts()
axes[0, 0].pie(functional_counts, labels=["No impairment", "Has impairment"],
               autopct="%1.1f%%", colors=["steelblue", "fuchsia"])
axes[0, 0].set_title("Overall Functional Impairment Rate\n(Difficulty with Errands)")

# Functional impairment rate by race/ethnicity
functional_by_race = df2.groupby("race_ethnicity")["functional_impairment"].mean().sort_values()
functional_by_race.plot(kind="barh", ax=axes[0, 1], color="fuchsia", edgecolor="white")
axes[0, 1].set_xlabel("Proportion with Impairment")
axes[0, 1].set_title("Functional Impairment Rate by Race/Ethnicity")

# Sleep hours by functional impairment status
df2.boxplot(column="sleep_hours", by="functional_impairment", ax=axes[0, 2])
axes[0, 2].set_xticklabels(["No impairment", "Has impairment"])
axes[0, 2].set_xlabel("Functional Impairment")
axes[0, 2].set_ylabel("Sleep Hours")
axes[0, 2].set_title("Sleep Hours by Functional Impairment")
plt.suptitle("")

# ── Cognitive Impairment (CNCRDIFF) ──────────────────────────────────────

# Overall cognitive impairment rate
cognitive_counts = df2["cognitive_impairment"].value_counts()
axes[1, 0].pie(cognitive_counts, labels=["No impairment", "Has impairment"],
               autopct="%1.1f%%", colors=["steelblue", "goldenrod"])
axes[1, 0].set_title("Overall Cognitive Impairment Rate\n(Difficulty Concentrating/Remembering)")

# Cognitive impairment rate by race/ethnicity
cognitive_by_race = df2.groupby("race_ethnicity")["cognitive_impairment"].mean().sort_values()
cognitive_by_race.plot(kind="barh", ax=axes[1, 1], color="goldenrod", edgecolor="white")
axes[1, 1].set_xlabel("Proportion with Impairment")
axes[1, 1].set_title("Cognitive Impairment Rate by Race/Ethnicity")

# Sleep hours by cognitive impairment status
df2.boxplot(column="sleep_hours", by="cognitive_impairment", ax=axes[1, 2])
axes[1, 2].set_xticklabels(["No impairment", "Has impairment"])
axes[1, 2].set_xlabel("Cognitive Impairment")
axes[1, 2].set_ylabel("Sleep Hours")
axes[1, 2].set_title("Sleep Hours by Cognitive Impairment")
plt.suptitle("")

plt.tight_layout()
plt.savefig("results/brfss_daytime_impairment.png", dpi=150)
plt.show()

print("\nFunctional Impairment Rate:")
print(df2["functional_impairment"].value_counts(normalize=True).mul(100).round(2))

print("\nCognitive Impairment Rate:")
print(df2["cognitive_impairment"].value_counts(normalize=True).mul(100).round(2))
# Out:
# Functional Impairment Rate:
# functional_impairment
# 0.0    91.17
# 1.0     8.83
# Name: proportion, dtype: float64
#
# Cognitive Impairment Rate:
# cognitive_impairment
# 0.0    78.02
# 1.0    21.98
# Name: proportion, dtype: float64

# %% [markdown]
# This figure displays the overall impairment rates, racial/ethnic disparities, and the relationship between sleep hours and daytime impairment for both functional and cognitive outcomes from the BRFSS 2022 dataset.
#
# In the top row, we are looking at functional impairment. Here 8.8% of respondents report difficulty doing errands alone, indicating a relatively rare but meaningful functional limitation in the sample. Further, non-Hispanic Other and Hispanic groups show the highest functional impairment rates (16–21%), while Non-Hispanic Asian and Non-Hispanic White groups show the lowest (7–8%), suggesting notable racial disparities. However, sleep hours are nearly identical between those with and without functional impairment, with both groups centered around 7 hours.
#
# In the bottom row, 22.0% report difficulty concentrating or remembering (more than double the functional impairment rate) suggesting cognitive limitations are more prevalent in this sample. The racial pattern is also different from functional impairment: Non-Hispanic Other and Non-Hispanic White groups show the highest cognitive impairment rates (23–25%), while Non-Hispanic Asian shows the lowest (~7%). Sleep hours appear similar between impaired and non-impaired groups, though those with cognitive impairment show a slightly wider spread of outliers on the high end.
#
# Neither impairment type shows a strong relationship with sleep hours alone in the boxplots, suggesting that impairment disparities may be better explained by the full set of predictors. This motivated the use of logistic regression models to formally test which demographic and socioeconomic factors significantly predict each impairment outcome after adjusting for mental health status

# %% [markdown]
# ### OLS Regressions
# An Ordinary Least Squares (OLS) regression model helps examine whether demographic and socioeconomic factors predict variation in sleep duration while controlling for mental health. The model includes age, gender, race/ethnicity, education level, income-to-poverty ratio, and mental health score as predictors.

# %% [markdown]
# #### NHANES - OLS Regression

# %%
import statsmodels.formula.api as smf
model = smf.ols("sleep_hours ~ age + income_ratio + mental_health_score + C(gender) + C(race_ethnicity) + C(education)",data=df1).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            sleep_hours   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     7.334
# Date:                Thu, 19 Mar 2026   Prob (F-statistic):           1.85e-14
# Time:                        04:12:42   Log-Likelihood:                -9744.8
# No. Observations:                5218   AIC:                         1.952e+04
# Df Residuals:                    5204   BIC:                         1.961e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# The model is statistically significant (F = 7.33, p < 0.001), indicating that the included variables collectively explain some variation in sleep duration, although the overall explanatory power is relatively low (R² = 0.018).
#
# Among the predictors, mental health score and income-to-poverty ratio show statistically significant relationships with sleep duration. The coefficient for mental health score is negative and significant (β = −0.025, p < 0.001), indicating that higher levels of depressive symptoms are associated with slightly fewer hours of sleep. The income-to-poverty ratio has a small but significant negative association with sleep duration (β = −0.052, p = 0.001), suggesting that individuals with higher income relative to the poverty line report marginally fewer hours of sleep.
#
# Gender also shows a statistically significant effect. The coefficient for males is negative (β = −0.119, p = 0.007), indicating that males report slightly fewer hours of sleep on average compared to females. Other variables, including most race/ethnicity categories, education levels, and age, do not show statistically significant associations with sleep duration at conventional significance levels.

# %% [markdown]
# #### BRFSS - OLS Regression

# %%
brfss_model = smf.ols("sleep_hours ~ C(age_group) + C(sex) + C(race_ethnicity) + income + C(education) + mental_health_days", data=df2).fit()

print("=" * 60)
print("OLS REGRESSION — Sleep Hours (BRFSS 2022)")
print("=" * 60)
print(brfss_model.summary())
# Out:
# ...
# OLS REGRESSION — Sleep Hours (BRFSS 2022)
# ...
#                             OLS Regression Results
# ...
# Dep. Variable:            sleep_hours   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     31.22
# Date:                Thu, 19 Mar 2026   Prob (F-statistic):          4.16e-145
# Time:                        04:12:44   Log-Likelihood:                -31703.
# No. Observations:               17791   AIC:                         6.346e+04
# Df Residuals:                   17765   BIC:                         6.366e+04
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# This OLS regression model predicting sleep hours from age, sex, race/ethnicity, income, education, and mental health days was statistically significant overall (F = 31.22, p < 0.001), indicating that the predictors collectively explain a meaningful portion of variance in sleep duration.
#
# However, the R-squared of 0.042 suggests that the model accounts for only about 4% of the variation in sleep hours, which is consistent with findings from the NHANES dataset and reflects the well-established complexity of sleep as an outcome not fully captured by demographic variables alone.
#
# The baseline predicted sleep duration was 6.79 hours, representing the reference categories across all predictors. Most age group coefficients were negative relative to the 18-24 reference group, suggesting slightly shorter sleep durations in older age groups, though these differences were not statistically significant.
#
# Overall, these results suggest that while the demographic and socioeconomic predictors included in the model are jointly significant, no single predictor dominates, which supports the importance of examining the full set of covariates, including mental health, when studying sleep disparities.

# %% [markdown]
# ### Logistic Regressions
#
# Since impairment is a yes/no response, logistic regression is needed to predict the probability that something belongs to one category or the other, keeping predictions bounded between 0 and 1, which makes it appropriate for binary outcomes. The model looks at sleep duration, age, gender, race/ethnicity, education level, income, and mental health score as predictors.

# %% [markdown]
# #### BRFSS Logistic Regressions

# %%
#functional impairment logistic regression
logit_functional = smf.logit(
    formula="""functional_impairment ~ sleep_hours + C(age_group) + C(sex) + 
               C(race_ethnicity) + income + C(education) + mental_health_days""",
    data=df2
).fit()

print("=" * 60)
print("LOGISTIC REGRESSION — Functional Impairment (BRFSS 2022)")
print("=" * 60)
pd.set_option('display.max_rows', None)
print(logit_functional.summary())

with open('results/logit_functional_summary.txt', 'w') as f:
    f.write(logit_functional.summary2().as_text())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.254662
#          Iterations 7
# ...
# LOGISTIC REGRESSION — Functional Impairment (BRFSS 2022)
# ...
#                              Logit Regression Results
# ...
# Dep. Variable:     functional_impairment   No. Observations:                17791
# Model:                             Logit   Df Residuals:                    17764
# Method:                              MLE   Df Model:                           26
# Date:                   Thu, 19 Mar 2026   Pseudo R-squ.:                  0.1471
# Time:                           04:13:27   Log-Likelihood:                -4530.7
# converged:                          True   LL-Null:                       -5312.3
# Covariance Type:               nonrobust   LLR p-value:                     0.000
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %% [markdown]
# The logistic regression predicting functional impairment (difficulty doing errands alone) was statistically significant overall (LLR p < 0.001), with a pseudo R-squared of 0.147, indicating the model explains roughly 15% of the variation in functional impairment (a meaningful fit for a logistic model).
#
# Regarding age, the 40-44 and 65-69 groups showed significantly lower odds of functional impairment compared to the 18-24 reference group (p = 0.038 and p = 0.015 respectively), though most other age groups did not reach significance. Furthermore, sex was a strong and significant predictor: males had significantly lower odds of functional impairment compared to females (coef = -0.44, p < 0.001), suggesting women are more likely to report difficulty with errands.
#
# Race and ethnicity were largely not statistically significant after controlling for other variables, with no racial/ethnic group reaching p < 0.05, though Non-Hispanic Black and multiracial groups showed positive trends.
#
# Education was a notable predictor given those with elementary education (p = 0.002) and some high school (p = 0.001) had significantly higher odds of functional impairment compared to the college graduate reference group, suggesting a clear SES gradient.
#
# Income was also highly significant and negative (coef = -0.25, p < 0.001), meaning higher income was strongly associated with lower odds of functional impairment. Mental health days were positively and significantly associated with functional impairment (coef = 0.059, p < 0.001), confirming that poorer mental health is linked to greater daytime functional limitations. Notably, sleep hours alone were not a significant predictor (p = 0.488), suggesting that functional impairment is more strongly driven by socioeconomic and mental health factors than sleep duration alone.

# %%
#cog impairment logistic regression
logit_cognitive = smf.logit(
    formula="""cognitive_impairment ~ sleep_hours + C(age_group) + C(sex) + 
               C(race_ethnicity) + income + C(education) + mental_health_days""",
    data=df2
).fit()

print("=" * 60)
print("LOGISTIC REGRESSION — Cognitive Impairment (BRFSS 2022)")
print("=" * 60)
pd.set_option('display.max_rows', None)
print(logit_cognitive.summary())

with open('results/logit_cognitive_summary.txt', 'w') as f:
    f.write(logit_cognitive.summary2().as_text())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.514067
#          Iterations 6
# ...
# LOGISTIC REGRESSION — Cognitive Impairment (BRFSS 2022)
# ...
#                             Logit Regression Results
# ...
# Dep. Variable:     cognitive_impairment   No. Observations:                17791
# Model:                            Logit   Df Residuals:                    17764
# Method:                             MLE   Df Model:                           26
# Date:                  Thu, 19 Mar 2026   Pseudo R-squ.:                 0.02397
# Time:                          04:14:07   Log-Likelihood:                -9145.8
# converged:                         True   LL-Null:                       -9370.4
# Covariance Type:              nonrobust   LLR p-value:                 1.007e-78
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %% [markdown]
# The logistic regression predicting cognitive impairment (difficulty concentrating or remembering) was statistically significant overall (LLR p < 0.001), though the pseudo R-squared of 0.024 indicates the model explains only about 2% of the variation in cognitive impairment (notably weaker than the functional impairment model). This suggests cognitive impairment is influenced by a broader set of factors not fully captured by the predictors included here.
#
# Age was a significant predictor, with older adults showing progressively higher odds of cognitive impairment compared to the 18-24 reference group. Specifically, the 70-74 (p = 0.032), 75-79 (p = 0.016), and 80+ (p = 0.006) groups all showed significantly elevated odds, reflecting the well-known association between aging and cognitive decline. Unlike functional impairment, sex was not a significant predictor of cognitive impairment (p = 0.686), suggesting cognitive limitations are similarly distributed across males and females in this sample.
#
# Race and ethnicity showed notable disparities. Non-Hispanic White (coef = 0.60, p < 0.001) and Non-Hispanic Other (coef = 0.71, p = 0.001) groups had significantly higher odds of cognitive impairment compared to the Hispanic reference group, while Non-Hispanic Asian respondents had significantly lower odds (coef = -0.75, p = 0.010).
#
# Education showed limited effects, with only high school graduates having marginally lower odds than college graduates (p = 0.034). Furthermore, income was not a significant predictor (p = 0.582), which contrasts sharply with the functional impairment model where income was one of the strongest predictors.
#
# Lastly, mental health days remained a significant positive predictor (coef = 0.017, p < 0.001), confirming that poorer mental health is associated with greater cognitive limitations. As with functional impairment, sleep hours alone were not a significant predictor of cognitive impairment (p = 0.492).

# %% [markdown]
# ## Ethics & Privacy

# %% [markdown]
# Because this project analyzes disparities in sleep duration and sleep-related impairment across demographic and socioeconomic groups, ethics and privacy considerations are central to both the research question and the way results are communicated. Our goal was not to treat demographic categories as biological explanations for sleep outcomes, but to examine whether sleep-related differences appear alongside broader social and structural inequalities.
#
# ### A. Data Collection
#
# - [X] **A.1 Informed consent**
#   We did not collect any new data or interact directly with human subjects. Instead, we used existing public health datasets that were originally collected by established survey programs. Consent and participation were handled by the original data collectors, and our project used only the publicly released versions of the data.
#
# - [X] **A.2 Collection bias**
#   We explicitly considered possible sources of collection bias. Both NHANES and BRFSS rely heavily on self-reported measures, so sleep duration, impairment, and mental health variables may be affected by recall bias, reporting bias, or differences in how respondents interpret survey questions. In addition, some populations may be underrepresented or systematically excluded due to survey design, nonresponse, language barriers, housing instability, or unequal access to healthcare systems. We addressed this by discussing these biases as limitations and by avoiding causal or overgeneralized claims.
#
# - [X] **A.3 Limit PII exposure**
#   Our analyses used de-identified public-use data and did not require direct personally identifiable information. We only retained variables relevant to the research question and did not attempt to identify individuals or reconstruct identities from combinations of variables.
#
# - [X] **A.4 Downstream bias mitigation**
#   Because this project examines protected and sensitive social categories, we took care to interpret those variables responsibly. We framed race/ethnicity, sex, education, and income as markers of social context rather than as innate causes. We also included mental health as an adjustment variable to reduce misleading interpretations that might otherwise attribute disparities solely to demographic categories.
#
# ### B. Data Storage
#
# - [X] **B.1 Data security**
#   Data and notebooks were stored in course-approved or university-managed environments and accessed only by project group members. We did not upload raw data containing sensitive health-related responses into public-facing outputs beyond what was already publicly released by the data providers.
#
# - [X] **B.2 Right to be forgotten**
#   Because we used pre-existing, public datasets, we had no ability to remove or alter individual records. For that reason, a direct right-to-be-forgotten mechanism was not something our group could implement.
#
# - [X] **B.3 Data retention plan**
#   We limited retention of local working copies of the data to the duration of the course project and did not create new person-level datasets beyond cleaned analytic subsets needed for the analysis. The final deliverable is the notebook and its outputs, not a redistribution of raw respondent data.
#
# ### C. Analysis
#
# - [X] **C.1 Missing perspectives**
#   We recognized that important drivers of sleep disparities are only partially captured in these datasets. Factors such as work schedule, caregiving burden, neighborhood noise, housing insecurity, discrimination, chronic stress, and access to care may shape sleep outcomes but are not fully represented in our models. We addressed this by discussing omitted context in the notebook and by avoiding claims that our selected variables offer a complete explanation of sleep inequality.
#
# - [X] **C.2 Dataset bias**
#   Before and during analysis, we examined variable distributions, missingness, and the composition of analytic samples. We acknowledge that filtering may change the makeup of the final sample and can introduce additional bias if missingness is not random. We also note that self-reported public health surveys may reflect existing institutional and social biases in both who is surveyed and how responses are recorded.
#
# - [X] **C.3 Honest representation**
#   We designed figures and written interpretations to communicate patterns clearly without overstating what the data show. We reported when effects were weak, inconsistent, or only significant at the model level, and we distinguished between associations with sleep duration and associations with daytime impairment. We also avoided language implying causation from cross-sectional results.
#
# - [X] **C.4 Privacy in analysis**
#   We did not report row-level examples, attempt re-identification, or highlight unusually specific combinations of demographic traits that could increase disclosure risk. Our visualizations and tables were intended to describe broad patterns, not individual cases.
#
# - [X] **C.5 Auditability**
#   Our workflow is reproducible through the notebook code, documented cleaning steps, and clearly labeled analysis sections. This makes it possible for others to review our decisions, identify weaknesses, and reproduce or revise the analysis if concerns arise.
#
# ### D. Modeling
#
# - [X] **D.1 Proxy discrimination**
#   We considered the possibility that some predictors, especially education and income, may be influenced by broader structural disadvantage. Rather than treating those variables as neutral or purely individual traits, we interpreted them within a broader social context and avoided normative judgments about groups with higher modeled risk.
#
# - [X] **D.2 Fairness across groups**
#   Our project was not a predictive system making decisions about individuals, so fairness was not evaluated through disparate error rates or allocation outcomes. Instead, fairness in this project meant checking whether group differences were being interpreted responsibly and whether the analysis could unintentionally reinforce stereotypes. We addressed this by comparing patterns across groups, reporting uncertainty, and centering structural explanations over individual blame.
#
# - [X] **D.3 Metric selection**
#   We treated sleep duration and sleep-related impairment as useful but incomplete indicators of sleep health. A person can report the same number of sleep hours as someone else while having very different sleep quality, daytime fatigue, or functional burden.
#
# - [X] **D.4 Explainability**
#   We used interpretable statistical models so that the direction and relative strength of associations could be explained in plain language. This was important because results involving demographic variables can be easily misunderstood if presented only as coefficients or significance tests without context.
#
# - [X] **D.5 Communicate limitations**
#   We clearly communicated that the project is correlational, based on cross-sectional and self-reported data, and subject to measurement and sampling limitations. We also noted that some analyses should be interpreted as patterns in the analytic sample rather than as definitive population-wide relationships.
#
# ### E. Deployment and Use of Results
#
# - [X] **E.1 Monitoring and evaluation**
#   This project is an exploratory analysis and was not deployed as a decision system. Because there is no live system affecting users, ongoing monitoring is not applicable in the usual sense.
#
# - [X] **E.2 Redress**
#   There is no automated decision process. However, we still considered the possibility of harm through interpretation and communication. To reduce that risk, we emphasized that observed disparities should not be used to stereotype demographic groups.
#
# - [X] **E.3 Roll back**
#   Since no model was deployed, rollback is not applicable. The closest analogue in this context is transparent documentation: because the full workflow is visible in the notebook, the analysis can be revised, corrected, or withdrawn if problems are identified.
#
# - [X] **E.4 Unintended use**
#   A major ethical risk of this project is that group-level differences in sleep outcomes could be misread as evidence of innate deficiency or personal failure. We actively worked against that interpretation by framing disparities as likely reflections of structural and contextual inequality, by avoiding causal claims, and by discussing limitations wherever appropriate. The appropriate use of our findings is to motivate more careful public health and social inquiry, not to rank, blame, or stereotype groups.
#
# Overall, our group handled ethics and privacy by minimizing exposure to sensitive data, using only de-identified public datasets, openly documenting limitations, and interpreting demographic associations carefully.

# %% [markdown]
# ## Discussion and Conclusion

# %% [markdown]
# Our project investigated whether demographic and socioeconomic factors such as age, sex, race/ethnicity, education, and income are associated with disparities in sleep duration and sleep-related impairment among U.S. adults. Using NHANES and BRFSS, we found that these relationships do exist, but they are more complex than a simple pattern of one group always sleeping less than another. Across our data analysis, the overall models were statistically meaningful, which suggests that the selected variables explain differences in sleep-related outcomes. However, the strength of those relationships varied depending on the specific outcome being observed. In particular, our results suggest that demographic and socioeconomic disparities are often more visible in **sleep-related impairment** than in **sleep duration alone**.
#
# When we look specifically at sleep duration, the evidence was more moderate than our hypothesis predicted. In both datasets, the regression models for sleep duration were significant overall, indicating that the predictors jointly contributed to explaining variation in sleep hours. At the same time, these models explained only a relatively small proportion of the total variation in sleep duration, showing that sleep is influenced by many additional biological, behavioral, and environmental factors not captured in our project. In NHANES, worse mental health, lower income-to-poverty ratio, and male sex were associated with slightly lower reported sleep duration, while many other demographic variables were weaker or not significant after adjustment. The BRFSS results showed a similar pattern: there was evidence of broad association at the model level, but no single demographic factor solely explained sleep duration differences once the other variables were included. In this sense, our findings partially support our hypothesis. Demographic and socioeconomic status appear to matter, but their effect on sleep quantity alone may be smaller than expected when mental health is taken into account.
#
# The impairment data analysis revealed a stronger and more informative pattern. In the BRFSS functional impairment model, lower income, lower education, and more poor mental health days were all associated with greater odds of experiencing sleep-related impairment, while males had lower odds relative to females. The cognitive impairment model was somewhat weaker overall, but still suggested that older adults and individuals reporting worse mental health experienced greater sleep-related difficulties during the day. These findings help connect our results back to the background literature. Prior work has shown that sleep disparities are shaped by broader social and structural inequalities, and our analysis extends that work by suggesting that these inequalities may be especially visible in how poor sleep affects daily functioning. In other words, two people may report similar amounts of sleep, but poor sleep may still have a heavier effect on individuals facing worse mental health or socioeconomic disadvantage. This broader view helps bring the different results together into a more coherent picture: sleep health disparities are not only about how long people sleep, but also about how sleep problems interfere with quality of life.
#
# That being said, our findings were not perfectly uniform, and some of the contradictory results are important to acknowledge. For example, several demographic variables that we expected to be strong predictors of sleep duration were weak or inconsistent once mental health and socioeconomic measures were included. One possible explanation is that some of the effects of demographic status may have been indirectly influenced by factors such as mental health, stress, income, education, work conditions, or access to healthcare. Another possibility is that sleep duration by itself is too limited a measure to fully capture sleep inequality. People can sleep the same number of hours but differ greatly in sleep quality, daytime fatigue, or ability to function. Differences between NHANES and BRFSS may also reflect differences in survey design, question wording, or how specific variables were measured and cleaned. These inconsistencies do not necessarily weaken our overall findings; instead, they suggest that the relationship between social inequality and sleep is multifaceted and may be better understood by studying both sleep duration and impairment together rather than relying on one or the other.
#
# There are also several important limitations to this work. Both NHANES and BRFSS are cross-sectional datasets, so our analysis can only identify associations rather than causal relationships. We cannot conclude that demographic or socioeconomic factors directly cause shorter sleep or greater impairment, only that they are related in our sample. Second, many of the variables used in this project are self-reported, which introduces the possibility of biases. Third, our analysis depended on respondents with complete data for the selected variables, so missingness may have affected the final analytic sample. Even with these limitations, the project still provides a meaningful analysis of how sleep disparities are linked to broader patterns of mental health and socioeconomic inequality. A useful next step would be to incorporate survey weights more fully, examine additional predictors such as employment schedule or neighborhood context, and use longitudinal data to better understand how sleep disparities develop over time. Overall, our project findings suggest that improving sleep health requires looking beyond individual behavior and considering the larger social conditions that shape how well people sleep and how strongly poor sleep affects their daily lives.
